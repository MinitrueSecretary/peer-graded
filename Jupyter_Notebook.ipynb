# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Wipu Watcharakajorn**
# Currently a Computer Engineering student

# %% [markdown]
# *I am interested in Data Science because I think Data Science will be important for my future career.
# The other reason is, well.., working with Data looks so cool, doesn't it?*

# %% [markdown]
# ### The code below take a list of numbers (numList), sort it, and print the result.

# %%
numList = [3,6,4,2]
numList.sort()
print(numList)
# Out:
# [2, 3, 4, 6]

# %% [markdown]
# >You know the rules, and so do I
#
# ~~Warning: The link below is a Rickroll~~
# ***
# <a href = 'https://www.youtube.com/watch?v=dQw4w9WgXcQ'>Just Kidding, Click me!</a>
